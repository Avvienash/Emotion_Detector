# %%
# !pip install text2emotion
# !pip install emoji==1.6.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
import text2emotion as te
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import text2emotion as te
#
# ModuleNotFoundError: No module named 'text2emotion'

# %%
text = "I am die"
te.get_emotion(text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 text = "I am die"
# ----> 2 te.get_emotion(text)
#
# File c:\Users\Avvienash\anaconda3\envs\my_pytorch_env\Lib\site-packages\text2emotion\__init__.py:2716, in get_emotion(input)
#    2713     # print(clean_text)
#    2714     return clean_text
# -> 2716 text = cleaning(input).split()
#    2717 emotion_values = []
#    2718 emotions = {"Happy": 0, "Angry": 0, "Surprise": 0, "Sad": 0, "Fear": 0}
#
# File c:\Users\Avvienash\anaconda3\envs\my_pytorch_env\Lib\site-packages\text2emotion\__init__.py:2700, in get_emotion.<locals>.cleaning(text)
#    2698 def cleaning(text):
#    2699     text = text.lower()
# -> 2700     text = emojis_extractor(text)
#    2701     text = re.sub(r'http\S+|www.\S+', '', text)
#    2702     text = removing_contradictions(text)
#
# ...
